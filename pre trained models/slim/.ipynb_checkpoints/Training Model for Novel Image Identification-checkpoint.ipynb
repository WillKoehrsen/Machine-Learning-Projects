# %% [markdown]
# # Training Inception V3 CNN for Novel Image Recognition Tasks

# %% [markdown]
# The Inception V3 pretrainined model has achieved 80% top-1 accuracy on the Imagenet test dataset consisting of 1000 classes of objects. However, if we want to classify objects not in the 1000 classes, we will need to train at least one layer of the convolutional neural network with a new training set. We will investigate training the Inception architecture for use in identifying faces by training the final layer of the network and adding on a new output layer. We will use the [Labeled Faces in the Wild](http://vis-www.cs.umass.edu/lfw/) dataset, which contains over 13000 images of faces collected from the internet. The original intention of the LFW dataset is to train face verification algorithms that, if given two individuals, can identify whether or not they are the same person. We will repurpose the dataset for our own use by keeping only the images from the 10 individuals with the most pictures. (There are 5749 people with at least 1 image and 1680 people with at least 2 photos in the full data). Limiting ourselves to the top 10 classes should allow us to alter the Inception network to distinguish the 10 different individuals and keep training times reasonable. This project was adapted from the TensorFlow Slim Walkthrough [Jupyter Notebook](https://github.com/tensorflow/models/blob/master/slim/slim_walkthrough.ipynb) and aided by the great book _Hands-On Machine Learning with Scikit-learn and TensorFlow_ by Aurelien Geron. All of the Jupyter Notebooks for the book can be found on the [book's GitHub](https://github.com/ageron/handson-ml).

# %%
# Trusty machine learning imports
import tensorflow as tf
import numpy as np

# %% [markdown]
# ## Download the Latest Checkpoint of Pre-Trained Model

# %% [markdown]
# We first have to get the latest version of the Inception v3 pre-trained model. The full list of available pre-trained models can be found on the TensorFlow Slim [GitHub page](https://github.com/tensorflow/models/tree/master/slim#pre-trained-models). The Inception v3 network achieved 78.0% top-1 accuracy on the ImageNet classification task.

# %%
from datasets import dataset_utils
import os

# Base url
TF_MODELS_URL = "http://download.tensorflow.org/models/"

# Modify this path for a different CNN
INCEPTION_V3_URL = TF_MODELS_URL + "inception_v3_2016_08_28.tar.gz"

# Directory to save model checkpoints
MODELS_DIR = "models/cnn"

INCEPTION_V3_CKPT_PATH = MODELS_DIR + "/inception_v3.ckpt"

# Make the model directory if it does not exist
if not tf.gfile.Exists(MODELS_DIR):
    tf.gfile.MakeDirs(MODELS_DIR)
 
# Download the appropriate model if haven't already done so
if not os.path.exists(INCEPTION_V3_CKPT_PATH):    
    dataset_utils.download_and_uncompress_tarball(INCEPTION_V3_URL, MODELS_DIR)

# %% [markdown]
# ## Download the Labeled Faces in the Wild Dataset

# %% [markdown]
# Now we will download the Labeled Faces in the Wild full dataset. I have chosen to use the deep-funneled images, a [process of image alignment](http://vis-www.cs.umass.edu/papers/nips2012_deep_congealing.pdf) that allows for better representation of the differences between faces by reducing the variability in the background of images. (In other words, one of the problems with face identification is that intra-class variability between images of the same individual can often be greater than inter-class variability between images of different individuals.) This method of processing has been demonstrated to improve accuracy on facial verification tasks compared to un-aligned images.

# %%
# Full deep-funneled images dataset
FACES_URL = "http://vis-www.cs.umass.edu/lfw/lfw-deepfunneled.tgz"
IMAGES_DOWNLOAD_DIRECTORY = "tmp/faces"
IMAGES_DIRECTORY = "images/faces"

if not os.path.exists(IMAGES_DOWNLOAD_DIRECTORY):
    os.makedirs(IMAGES_DOWNLOAD_DIRECTORY)

# If the file has not already been downloaded, retrieve and extract it
if not os.path.exists(IMAGES_DOWNLOAD_DIRECTORY + "/lfw-deepfunneled.tgz"):
    dataset_utils.download_and_uncompress_tarball(FACES_URL, IMAGES_DOWNLOAD_DIRECTORY)
# Out:
# >> Downloading lfw-deepfunneled.tgz 100.0%
# Successfully downloaded lfw-deepfunneled.tgz 108761145 bytes.

# %%
# List of all the individuals in the full dataset
people = os.listdir(path="tmp/faces/lfw-deepfunneled")
print("There are {} people in the full lfw dataset.".format(len(people)))
# Out:
# There are 5749 people in the full lfw dataset.

# %% [markdown]
# ## Sort Individual's Directories by Number of Images

# %% [markdown]
# Some of the names only have 1 photo associated with them in the dataset which means even the powerful Inception CNN will never have a chance to properly learn to identify that individual. We will keep the 10 individuals with the greatest numbers of photo in the dataset which should give the CNN at least a chance of learning to distinguish between the 10 classes. In an ideal situation, we would have thousands of examples from each class, but we will have to make do with the available data.
#
# We can sort the individuals by the number of photos in the database and then move the top 10 into a new directory. We will rename each folder with the number of photos in the directory and the name of the individual. This will allow us to quickly create the images and labels for the training, validation, and testing datasets.

# %%
people_number = []

# Count number of photos of each individual. People number is a list of tuples 
# with each tuple composed of the name and the number of photos of a person.
for person in people:
    folder_path = IMAGES_DOWNLOAD_DIRECTORY + '/lfw-deepfunneled/' + person
    num_images = len(os.listdir(folder_path))
    people_number.append((person, num_images))
    
# Sort the list of tuples by the number of images
people_number = sorted(people_number, key=lambda x: x[1], reverse=True)

# %%
# Two methods for determining the number of people with a single image

# List Comprehension
people_with_one_photo = [(person) for person, num_images in people_number if num_images==1]
print("Individuals with one photo: {}".format(len(people_with_one_photo)))

# Filtering operation
print(len(list(filter(lambda x: x[1] == 1, people_number))))
# Out:
# Individuals with one photo: 4069
# 4069

# %%
from distutils.dir_util import copy_tree

# Number of individuals to retain
num_classes = 10

# Make the images directory if it does not exist
if not os.path.exists(IMAGES_DIRECTORY):
    os.mkdir(IMAGES_DIRECTORY)
    
    # Take the ten folders with the most images and move to new directory
    # Rename the folders with the number of images and name of individual
    for person in people_number[:num_classes]:
        name = person[0]
        # Original download directory path
        folder_path = IMAGES_DOWNLOAD_DIRECTORY + '/lfw-deepfunneled/' + name
        formatted_num_images = str(person[1]).zfill(3)
        new_folder_name = "{} {}".format(formatted_num_images, name)
        image_new_name = IMAGES_DIRECTORY + "/" + new_folder_name
        
        # Make a new folder for each individual in the images directory
        os.mkdir(IMAGES_DIRECTORY + '/' + name)
        # Copy the folder from the download location to the new folder
        copy_tree(folder_path, IMAGES_DIRECTORY + '/' + name)
        # Rename the folder with images and individual
        os.rename(IMAGES_DIRECTORY + '/' + name, image_new_name)

# %%
os.listdir("images/faces")
# Out:
# ['053 John_Ashcroft',
#  '055 Jean_Chretien',
#  '060 Junichiro_Koizumi',
#  '071 Hugo_Chavez',
#  '077 Ariel_Sharon',
#  '109 Gerhard_Schroeder',
#  '121 Donald_Rumsfeld',
#  '144 Tony_Blair',
#  '236 Colin_Powell',
#  '530 George_W_Bush']

# %%
for person in people_number[:num_classes]:
    print('{:26}  {:10} images'.format(*person))
# Out:
# George_W_Bush                      530 images
# Colin_Powell                       236 images
# Tony_Blair                         144 images
# Donald_Rumsfeld                    121 images
# Gerhard_Schroeder                  109 images
# Ariel_Sharon                        77 images
# Hugo_Chavez                         71 images
# Junichiro_Koizumi                   60 images
# Jean_Chretien                       55 images
# John_Ashcroft                       53 images

# %% [markdown]
# Based on the printed directory content and a manual inspection of the directory, it appears that we have only the top 10 individuals with the most images in our new image training directory. Now it will be relatively simple to create the training, validation, and testing datasets from these directories.

# %% [markdown]
# ## Creating Training, Validation, and Testing Datasets

# %% [markdown]
# Now that the images are in the right place and we have our 10 individuals that constitute the classes (which seem to be a bit heavy on the world leaders) we can split the data into training, validation, and testing data. Unfortunately, we can see that we do not have very much data on some of the individuals. 50 images is an extremely small sample size in the world of machine learning, particularly for neural networks, but we can use some data augmentation techniques to artificially expand the dataset. We can also see that we have uneven class distributions with George W Bush and Colin Powell comprising more than half of the images between them. This could also affect the results because we might create a network that is adept at identifying Bush and Powell and no one else. For now, we will use only the original deep-funneled images and see what we can accomplish by training a single layer of the Inception V3 CNN.
#
# The next step is to split the data into training, validation, and testing datasets. I want to retain as many training images as possible, but still need a validation set to implement early stopping to prevent overfitting on the training data. The testing set should also be fairly large size in order to reliably assess the accuracy of the trained network. We will retain 70% of each class for a training set, %5 for a validation set, and 25% for a testing set.

# %% [markdown]
# #### Map each class to an integer label

# %%
class_mapping = {}
class_images = {}

# Create dictionary to map integer labels to individuals
# Class_images will record number of images for each class
for index, directory in enumerate(os.listdir("images/faces")):
    class_mapping[index] = directory.split(" ")[1]
    class_images[index] = int(directory.split(' ')[0])

# %%
class_mapping
# Out:
# {0: 'John_Ashcroft',
#  1: 'Jean_Chretien',
#  2: 'Junichiro_Koizumi',
#  3: 'Hugo_Chavez',
#  4: 'Ariel_Sharon',
#  5: 'Gerhard_Schroeder',
#  6: 'Donald_Rumsfeld',
#  7: 'Tony_Blair',
#  8: 'Colin_Powell',
#  9: 'George_W_Bush'}

# %%
class_images
# Out:
# {0: 53, 1: 55, 2: 60, 3: 71, 4: 77, 5: 109, 6: 121, 7: 144, 8: 236, 9: 530}

# %% [markdown]
# #### We can look at the distribution of each class.

# %%
total_num_images = np.sum(list(class_images.values()))

print("Individual \t Composition of Dataset\n")
for label, num_images in class_images.items():
    print("{:20} {:.2f}%".format(
        class_mapping[label], (num_images / total_num_images) * 100))
# Out:
# Individual 	 Composition of Dataset
#
# John_Ashcroft        3.64%
# Jean_Chretien        3.78%
# Junichiro_Koizumi    4.12%
# Hugo_Chavez          4.88%
# Ariel_Sharon         5.29%
# Gerhard_Schroeder    7.49%
# Donald_Rumsfeld      8.31%
# Tony_Blair           9.89%
# Colin_Powell         16.21%
# George_W_Bush        36.40%

# %% [markdown]
# #### Read the images into RGB (red-green-blue) pixel value arrays.

# %%
import matplotlib.pyplot as plt

image_arrays = []
image_labels = []
root_image_directory = "images/faces/"

for label, person in class_mapping.items():
    for directory in os.listdir(root_image_directory):
        if directory.split(" ")[1] == person:
            image_directory = root_image_directory + directory
            break
            
    for image in os.listdir(image_directory):
        image = plt.imread(os.path.join(image_directory, image))
        image_arrays.append(image)
        image_labels.append(label)

# %%
image_arrays = np.array(image_arrays)
image_labels = np.array(image_labels)

print(image_arrays.shape, image_labels.shape)
# Out:
# (1456, 250, 250, 3) (1456,)

# %% [markdown]
# #### Split the images and labels into appropriately sized training, validation, and testing datasets.

# %%
import math
from collections import Counter

# Fractions for each dataset
train_frac = 0.70
valid_frac = 0.05
test_frac = 0.25
 
# This function takes in np arrays of images and labels along with split fractions
# and returns the six data arrays corresponding to each dataset as the appropriate type
def create_data_splits(X, y, train_frac=train_frac, test_frac=test_frac, valid_frac=valid_frac):
    X = np.array(X)
    y = np.array(y)
    
    # Make sure that the fractions sum to 1.0
    assert (test_frac + valid_frac + train_frac == 1.0), "Test + Valid + Train Fractions must sum to 1.0"
    
    X_raw_test = []
    X_raw_valid = []
    X_raw_train = []
    
    y_raw_test = []
    y_raw_valid = []
    y_raw_train = []
    
    # Randomly order the data and labels
    random_indices = np.random.permutation(len(X))
    X = X[random_indices]
    y = y[random_indices]
    
    for image, label in zip(X, y):
        
        # Number of images that correspond to desired fraction
        test_length = math.floor(test_frac * class_images[label])
        valid_length = math.floor(valid_frac * class_images[label])
        
        # Check to see if the datasets have the right number of labels (and images)
        if Counter(y_raw_test)[label] < test_length:
            X_raw_test.append(image)
            y_raw_test.append(label)
        elif Counter(y_raw_valid)[label] < valid_length:
            X_raw_valid.append(image)
            y_raw_valid.append(label)
        else:
            X_raw_train.append(image)
            y_raw_train.append(label)
            
    return np.array(X_raw_train, dtype=np.float32), np.array(X_raw_valid, dtype=np.float32), np.array(X_raw_test, dtype=np.float32), np.array(y_raw_train, dtype=np.int32), np.array(y_raw_valid, dtype=np.int32), np.array(y_raw_test, dtype=np.int32)

# %%
# Create all the testing splits using the create_splits function
X_train, X_valid, X_test, y_train, y_valid, y_test = create_data_splits(image_arrays, image_labels)

# %%
(X_valid.shape[0] + X_test.shape[0] + X_train.shape[0] == len(image_arrays))
# Out:
# True

# %%
(y_valid.shape[0] + y_test.shape[0] + y_train.shape[0] == len(image_labels))
# Out:
# True

# %%
# Check the number of images in each dataset split
print(X_train.shape, X_valid.shape, X_test.shape)
print(y_train.shape, y_valid.shape, y_test.shape)
# Out:
# (1027, 250, 250, 3) (68, 250, 250, 3) (361, 250, 250, 3)
# (1027,) (68,) (361,)

# %% [markdown]
# It looks like the data wrangling step is now complete. We have the appropriate training, validation, and testing images and labels datasets. When we run the training, we will use the validation set to implement early stopping. We run the training set through the model one small batch at a time and test the loss at each epoch with the entire validation set. The validation set is therefore limited by the number of images we can feed through the network at one time, which is determined by the memory of my GPU. I only have 2 GB on my [Nvidia GeForce 940M](https://www.geforce.com/hardware/notebook-gpus/geforce-940mx) and after some trial and error, I discovered that 68 validation images was about the limit that my card could hold in memory (along with all the model parameters). When we use the test set to determine the accuracy, we will use a small batch size and iterate through the set in order to test on all the instances.

# %% [markdown]
# ## Visualize Images in Each Class

# %%
# Import matplotlib and use magic command to plot in notebook
import matplotlib.pyplot as plt
# %matplotlib inline

# Function to plot an array of RGB values 
def plot_color_image(image):
    plt.figure(figsize=(4,4))
    plt.imshow(image.astype(np.uint8), interpolation='nearest')
    plt.axis('off')

# %%
import random

# PLot 2 examples from each class
num_examples = 2

# Iterate through the classes and plot 2 images from each
for class_number, person in class_mapping.items():
    print('{} Number of Images: {}'.format(person, class_images[class_number]))
    example_images = []
    while len(example_images) < num_examples:
        random_index = np.random.randint(len(X_train))
        if y_train[random_index] == class_number:
            example_images.append(X_train[random_index])
            
    for i, image in enumerate(example_images):
        plt.subplot(100 + num_examples*10 + i + 1)
        plt.imshow(image.astype(np.uint8), interpolation='nearest')
        plt.axis('off')
    plt.show()
# Out:
# John_Ashcroft Number of Images: 53
# Jean_Chretien Number of Images: 55
# Junichiro_Koizumi Number of Images: 60
# Hugo_Chavez Number of Images: 71
# Ariel_Sharon Number of Images: 77
# Gerhard_Schroeder Number of Images: 109
# Donald_Rumsfeld Number of Images: 121
# Tony_Blair Number of Images: 144
# Colin_Powell Number of Images: 236
# George_W_Bush Number of Images: 530

# %% [markdown]
# ## Process the Images for Use in the Inception CNN

# %% [markdown]
# The Inception CNN has been trained on images that are 299 x 299 x 3 (height by width by 3 color channels) where each value in each color channel is the pixel intensity of that color at that location. Color intensities range from 0-255, but the Inception net takes inputs that are normalized between 0 and 1 (which simply means dividing the raw values by 255). Our images will need to be resized  from 255 x 255 x 3 and the values normalized. We will actually feed the images through the processing step during training.

# %%
from scipy.misc import imresize

# Function takes in an image array and returns the resized and normalized array
def prepare_image(image, target_height=299, target_width=299):
    image = imresize(image, (target_width, target_height))
    return image.astype(np.float32) / 255

# %% [markdown]
# ## Determine the Layer of CNN to Train

# %% [markdown]
# The next step is to figure out what the last trainable layer (right before the outputs) is that we can unfreeze to use to learn the new classes. The inception_v3 function returns the logits and the endpoints. The logits are the unscaled outputs fromm the neural network while the end points are a dictionary of values returned from different stages of the last layer of the network. By looking at the end points dictionary, we can determine the precise level of the network we need to train.

# %%
from nets import inception 
from tensorflow.contrib import slim

tf.reset_default_graph()

X = tf.placeholder(tf.float32, [None, 299, 299, 3], name='X')
is_training = tf.placeholder_with_default(False, [])

# Run inception function to determine endpoints
with slim.arg_scope(inception.inception_v3_arg_scope()):
    logits, end_points = inception.inception_v3(X, num_classes=1001, is_training=is_training)

# Create saver of network before alterations
inception_saver = tf.train.Saver()

# %%
end_points
# Out:
# {'AuxLogits': <tf.Tensor 'InceptionV3/AuxLogits/SpatialSqueeze:0' shape=(?, 1001) dtype=float32>,
#  'Conv2d_1a_3x3': <tf.Tensor 'InceptionV3/InceptionV3/Conv2d_1a_3x3/Relu:0' shape=(?, 149, 149, 32) dtype=float32>,
#  'Conv2d_2a_3x3': <tf.Tensor 'InceptionV3/InceptionV3/Conv2d_2a_3x3/Relu:0' shape=(?, 147, 147, 32) dtype=float32>,
#  'Conv2d_2b_3x3': <tf.Tensor 'InceptionV3/InceptionV3/Conv2d_2b_3x3/Relu:0' shape=(?, 147, 147, 64) dtype=float32>,
#  'Conv2d_3b_1x1': <tf.Tensor 'InceptionV3/InceptionV3/Conv2d_3b_1x1/Relu:0' shape=(?, 73, 73, 80) dtype=float32>,
#  'Conv2d_4a_3x3': <tf.Tensor 'InceptionV3/InceptionV3/Conv2d_4a_3x3/Relu:0' shape=(?, 71, 71, 192) dtype=float32>,
#  'Logits': <tf.Tensor 'InceptionV3/Logits/SpatialSqueeze:0' shape=(?, 1001) dtype=float32>,
#  'MaxPool_3a_3x3': <tf.Tensor 'InceptionV3/InceptionV3/MaxPool_3a_3x3/MaxPool:0' shape=(?, 73, 73, 64) dtype=float32>,
# ...

# %% [markdown]
# The neurons that we want to train are the PreLogits because they come right before the predictions. We will also have to create a new output layer (Predictions). Notice that the current predictions have a shape of (None, 1001) indicating the 1000 classes in the ImageNet data plus the 'background' class that is created when the argument is_training=True.

# %% [markdown]
# ## Specify Training and Output Layer

# %% [markdown]
# What we are doing here is essentially "unfreezing" the PreLogits layer. All of the previous layers will retain the weights and biases that they learned on the 1.2 million images with which Google trained the Inception net. Only a single layer will learn new weights and biases that allow for the identification of faces.

# %%
# Isolate the trainable layer
prelogits = tf.squeeze(end_points['PreLogits'], axis=[1,2])

# Define the training layer and the new output layer
n_outputs = len(class_mapping)
with tf.name_scope("new_output_layer"):
    people_logits = tf.layers.dense(prelogits, n_outputs, name="people_logits")
    probability = tf.nn.softmax(people_logits, name='probability')

# %%
# Placeholder for labels
y = tf.placeholder(tf.int32, None)

# Loss function and training operation
# The training operation is passed the variables to train which includes only the single layer
with tf.name_scope("train"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=people_logits, labels=y)
    loss = tf.reduce_mean(xentropy)
    optimizer = tf.train.AdamOptimizer(learning_rate=0.01)
    # Single layer to be trained
    train_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope="people_logits")
    # The variables to train are passed to the training operation
    training_op = optimizer.minimize(loss, var_list=train_vars)
    
# Accuracy for network evaluation
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(predictions=people_logits, targets=y, k=1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
    
# Intialization function and saver
with tf.name_scope("init_and_saver"):
    init = tf.global_variables_initializer()
    saver = tf.train.Saver()

# %% [markdown]
# ## Define Function to Create Batches of Processed Images

# %%
# Function takes in an array of images and labels and processes the images to create
# a batch of a given size
def create_batch(X, y, start_index=0, batch_size=4):
    
    stop_index = start_index + batch_size
    prepared_images = []
    labels = []
    
    for index in range(start_index, stop_index):
        prepared_images.append(prepare_image(X[index]))
        labels.append(y[index])
        
    # Combine the images into a single array by joining along the 0th axis
    X_batch = np.stack(prepared_images)
    # Combine the labels into a single array
    y_batch = np.array(labels, dtype=np.int32)
    
    return X_batch, y_batch

# %%
X_valid, y_valid = create_batch(X_valid, y_valid, 0, len(X_valid))

# %%
print(X_valid.shape, y_valid.shape)
# Out:
# (68, 299, 299, 3) (68,)

# %% [markdown]
# The function looks like it correctly process the images and returned the batch as we specified. We can use this function when training or evaluating to iterate through the training and testing set respectively. We process the entire validation set ahead of time because we will be passing all the validation examples through the network at once during training.

# %% [markdown]
# ### TensorBoard File Writing Operations

# %% [markdown]
# We will want to visualize the training accuracy, and validation accuracy and loss to determine if we are overfitting and to gauge the progress over the iterations. We can also look at the structure of the network using TensorBoard. To do so, we need to specify the figures to track and write to the FileWriter at appropriate times.

# %%
with tf.name_scope("tensorboard_writing"):
    # Track validation accuracy and loss and training accuracy
    valid_acc_summary = tf.summary.scalar(name='valid_acc', tensor=accuracy)
    valid_loss_summary = tf.summary.scalar(name='valid_loss', tensor=loss)
    train_acc_summary = tf.summary.scalar(name='train_acc', tensor=accuracy)

    # Merge the validation stats
    valid_merged_summary = tf.summary.merge(inputs=[valid_acc_summary, valid_loss_summary])

# %%
# Use the time to differentiate the different training sessions
from datetime import datetime
import time

# %% [markdown]
# We load in the entire pre-trained model using the saver we defined before modifying the network. Then, during training, we use the newly defined second to last layer and output layer to adjust the parameters (weights and biases) of the trainable layer to learn the novel classes. We then can save the trained model for use when evaluating the performance on the test set.

# %% [markdown]
# ## Train on Novel Classes

# %%
n_epochs = 100
batch_size = 32

# Early stopping parameters
max_checks_without_progress = 20
checks_without_progress = 0
best_loss = np.float("inf")

# Show progress every show_progress epochs
show_progress = 1

# Want to iterate through the entire training set every epoch
n_iterations_per_epoch = len(X_train) // batch_size

# Specify the directory for the FileWriter
now = datetime.now().strftime("%Y%m%d_%H%M%S")
model_dir = "{}_unaugmented".format(now)
logdir = "tensorboard/faces/" + model_dir
file_writer = tf.summary.FileWriter(logdir=logdir, graph=tf.get_default_graph())

# This is the pre-trained model checkpoint training path
inception_v3_checkpoint_path = "models/cnn/inception_v3.ckpt"

# This is the checkpoint path for our trained model with no dataaugmentation
unaugmented_training_path = "models/cnn/inception_v3_faces_unaugmented.ckpt"

with tf.Session() as sess:
    init.run()
    # Restore all the weights from the original CNN
    inception_saver.restore(sess, inception_v3_checkpoint_path)
    
    t0 = time.time()
    for epoch in range(n_epochs):
        start_index = 0
        # Each epoch, iterate through all the training instances
        for iteration in range(n_iterations_per_epoch):
            X_batch, y_batch = create_batch(X_train, y_train, start_index, batch_size)
            # Train the trainable layer 
            sess.run(training_op, {X: X_batch, y: y_batch})
            start_index += batch_size
            
        # Display the progress of training and write to the TensorBoard directory
        # for later visualization of the training
        if epoch % show_progress == 0:
            train_summary = sess.run(train_acc_summary, {X: X_batch, y: y_batch})
            file_writer.add_summary(train_summary, (epoch+1))
            #Size for validation limited by GPU memory (68 images will work)
            valid_loss, valid_acc, valid_summary = sess.run([loss, accuracy, valid_merged_summary], {X: X_valid, y: y_valid})
            file_writer.add_summary(valid_summary, (epoch+1))
            print('Epoch: {:4} Validation Loss: {:.4f} Accuracy: {:4f}'.format(
                epoch+1, valid_loss, valid_acc))
          
        # Check to see if network is still improving, if improved during epoch
        # a snapshot of the model will be saved to retain the best model
        if valid_loss < best_loss:
            best_loss = valid_loss
            checks_without_progess = 0
            save_path = saver.save(sess, unaugmented_training_path)
            
        # If network is not improving for a specified number of epochs, stop training
        else:
            checks_without_progress += 1
            if checks_without_progress > max_checks_without_progress:
                print('Stopping Early! Loss has not improved in {} epochs'.format(
                    max_checks_without_progress))
                break
                
    t1 = time.time()
    
print('Total Training Time: {:.2f} minutes'.format( (t1-t0) / 60))
# Out:
# INFO:tensorflow:Restoring parameters from models/cnn/inception_v3.ckpt
# Epoch:    1 Validation Loss: 1.5990 Accuracy: 0.529412
# Epoch:    2 Validation Loss: 1.4184 Accuracy: 0.632353
# Epoch:    3 Validation Loss: 1.2879 Accuracy: 0.573529
# Epoch:    4 Validation Loss: 1.2286 Accuracy: 0.632353
# Epoch:    5 Validation Loss: 1.2880 Accuracy: 0.573529
# Epoch:    6 Validation Loss: 1.5739 Accuracy: 0.455882
# Epoch:    7 Validation Loss: 1.9480 Accuracy: 0.500000
# Epoch:    8 Validation Loss: 1.7751 Accuracy: 0.441176
# Epoch:    9 Validation Loss: 1.3545 Accuracy: 0.558824
# Epoch:   10 Validation Loss: 1.3300 Accuracy: 0.544118
# Epoch:   11 Validation Loss: 1.7363 Accuracy: 0.514706
# Epoch:   12 Validation Loss: 2.1920 Accuracy: 0.323529
# Epoch:   13 Validation Loss: 1.4529 Accuracy: 0.558824
# Epoch:   14 Validation Loss: 1.8442 Accuracy: 0.455882
# Epoch:   15 Validation Loss: 2.6073 Accuracy: 0.485294
# Epoch:   16 Validation Loss: 2.7186 Accuracy: 0.485294
# ...

# %% [markdown]
# ## Evaluate on the Test Set

# %% [markdown]
# We cannot pass all the testing images through the model at once so we can do it one batch at a time. This evaluation will give us a good idea if this task is even feasible using the pretrained Inception CNN.

# %%
eval_batch_size = 32
n_iterations = len(X_test) // eval_batch_size

with tf.Session() as sess:
    # Restore the new trained model 
    saver.restore(sess, unaugmented_training_path)
    
    start_index = 0
    # Create a dictionary to store all the accuracies
    test_acc = {}
    
    t0 = time.time()
    # Iterate through entire testing set one batch at a time
    for iteration in range(n_iterations):
        X_test_batch, y_test_batch = create_batch(X_test, y_test, start_index, batch_size=eval_batch_size)
        test_acc[iteration] = accuracy.eval({X: X_test_batch, y:y_test_batch})
        start_index += eval_batch_size

        print('Iteration: {} Batch Testing Accuracy: {:.2f}%'.format(
            iteration+1, test_acc[iteration] * 100))
    
    t1 = time.time()
    
    # Final accuracy is mean of each batch accuracy
    print('\nFinal Testing Accuracy: {:.4f}% on {} instances.'.format(
        np.mean(list(test_acc.values())) * 100, len(X_test)))
    print('Total evaluation time: {:.4f} seconds'.format((t1-t0)))
# Out:
# INFO:tensorflow:Restoring parameters from models/cnn/inception_v3_faces_unaugmented.ckpt
# Iteration: 1 Batch Testing Accuracy: 65.62%
# Iteration: 2 Batch Testing Accuracy: 68.75%
# Iteration: 3 Batch Testing Accuracy: 53.12%
# Iteration: 4 Batch Testing Accuracy: 59.38%
# Iteration: 5 Batch Testing Accuracy: 62.50%
# Iteration: 6 Batch Testing Accuracy: 68.75%
# Iteration: 7 Batch Testing Accuracy: 68.75%
# Iteration: 8 Batch Testing Accuracy: 71.88%
# Iteration: 9 Batch Testing Accuracy: 59.38%
# Iteration: 10 Batch Testing Accuracy: 62.50%
# Iteration: 11 Batch Testing Accuracy: 46.88%
#
# Final Testing Accuracy: 62.5000% on 361 instances.
# Total evaluation time: 30.0208 seconds

# %% [markdown]
# That accuracy is surprisingly good! Keep in mind, that this is a neural network designed to identify 1000 different objects, none of which are people and we are trying to have it distinguish between 10 different individuals (a task I think some humans may have difficulty with) and some of the classes only have 50 images! I would not expect this high of an accuracy, but it shows that the features that distinguish images are not always obvious to us humans. We would not think that the same things that differentiate objects also distinguish human faces, but that appears to be the case. The lower layers of the convolutional neural network, which typically identify lower level broad features, have not been trained and retain all of their parameters from the ImageNet training while only the last layer of neurons, that which learns the highest level features, is trained.
#
# The next step is naturally to aim for better accuracy by augmenting the dataset. There are many approaches to increase the amount of data. The simplest is to gather more labeled images. The second best option, and the one we will employ, is to artificially expand the dataset by applying transformations to the images that do not affect the content of features in the image, but rather the presentation of these features. For example, the location of the face within the photo should not matter as the orientation of the face also should not make a difference. If the faces themselves are the same, then we want our algorithm to identify that they represent the same individual rather than predict that the individuals are different because they were oriented differently. Therefore, our network should be __invariant__ to certain shifts of the images. In effect, we are creating a network that is robust to manipulations of the orientation of the images and only learns to differentiate the content in the faces themselves. We do this by taking the exisiting images, applying a transformation, appending the transformed images to the training dataset (with the correct label), and then training the network again. We can train from scratch (or at least the final layer will be completely trained) or we can train the network from where it left off on the unaugmented dataset. We will try to retrain from scratch first to compare the accuracy we can achieve.

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ### Shifting Images

# %% [markdown]
# The first transformation will be to __shift__ the image by 30 pixels in each direction. This will create four additional images for each original image, effectively making the dataset 5x bigger. This shift should help to make the algorithm robust to changes in location of the face within the image. Tensorflow has built in functions to augment data, particularly images, but we can also use other libraries so we do not have to run the process in a Tensorflow session. For the shift transformation, the iamge will be shifted by a specified [dx, dy] and then the overlapping pixels will be set to a value of 255.

# %%
import scipy

# Take in an image as an array and return image with a [dx, dy] shift
def shift_image(image_array, shift):
    return scipy.ndimage.interpolation.shift(image_array, shift, cval=0)

# %%
# Four shifts of 30 pixels 
shifts = [[30,0], [-30,0], [0, 30], [0,-30]]
shifted_images = []
shifted_labels = []

# Iterate through all training images
for image, label in zip(X_train, y_train):
    
    # Swap the color channel and height axis 
    layers = np.swapaxes(image, 0, 2)
    
    # Apply four shifts to each original image
    for shift in shifts:
        transposed_image_layers = []
        
        # Apply the shift to the image one layer at a time
        # Each layer is an RGB color channel
        for layer in layers:
            transposed_image_layers.append(shift_image(layer, shift))
            
        # Stack the RGB layers to get one image and reswap the axes
        transposed_image = np.stack(transposed_image_layers)
        transposed_image = np.swapaxes(transposed_image, 0, 2)
        
        # Add the shifted images and the labels to a list
        shifted_images.append(transposed_image)
        shifted_labels.append(label)

# %%
# Convert the images and labels to numpy arrays
shifted_images = np.array(shifted_images)
shifted_labels = np.array(shifted_labels)

# %%
print(shifted_images.shape,shifted_labels.shape)
# Out:
# (4108, 250, 250, 3) (4108,)

# %% [markdown]
# It looks like the shifts we applied were successful. We can visualize the effect of the shift by taking a look at a few images.

# %%
ex_index = 2

# Plot original image
plot_color_image(X_train[ex_index])
plt.title("Original Image of {}".format(class_mapping[y_train[ex_index]]))
plt.show()

ex_shifted_images = shifted_images[ex_index*4:(ex_index*4)+ 4]

# Plot four shifted images
for i, image in enumerate(ex_shifted_images):
    shift = shifts[i]
    plt.subplot(2,2,i+1)
    plt.imshow(image.astype(np.uint8), interpolation='nearest')
    plt.title('Shift: {}'.format(shift))
    plt.axis('off')
plt.show()

# %%
ex_index = 5

# Plot original image
plot_color_image(X_train[ex_index])
plt.title("Original Image of {}".format(class_mapping[y_train[ex_index]]))
plt.show()

ex_shifted_images = shifted_images[ex_index*4:(ex_index*4)+ 4]

# Plot four shifted images
for i, image in enumerate(ex_shifted_images):
    shift = shifts[i]
    plt.subplot(2,2,i+1)
    plt.imshow(image.astype(np.uint8), interpolation='nearest')
    plt.title('Shift: {}'.format(shift))
    plt.axis('off')
plt.show()

# %% [markdown]
# Looking at the plotted images, I would say that the shifts have been successful. It may not seem like a large change, but at the very least, we now have a dataset that is five times larger. Perhaps it is better to shift the images by more or less, or to do shifts in two directions at once, but for now, we will start with the four simple left, right, down, up shifts picture above.

# %%
# Create a new training set with the original and shifted images
X_train_exp = np.concatenate((shifted_images, X_train))
y_train_exp = np.concatenate((shifted_labels, y_train))

# %%
# Randomize the order of the shifted images
random_indices = np.random.permutation(len(X_train_exp))

X_train_exp = X_train_exp[random_indices]
y_train_exp = y_train_exp[random_indices]

# %%
print(X_train_exp.shape, y_train_exp.shape)
# Out:
# (5135, 250, 250, 3) (5135,)

# %% [markdown]
# ### Training on Augmented Dataset

# %% [markdown]
# Everything looks good for another training round. We will start off the training with a clean pre-trained model. The training parameters are identical except for the number of training images. This training will take substantially longer than the first training, so find something worthwhile to do in the meantime! We will also change the model directory for the TensorBoard FileWriter as well as the save location for the model. We want to be able to restore whichever model performs the absolute best, which requires saving each model (one of the nets takes up about 100 MB of space).

# %%
n_epochs = 100
batch_size = 32
max_checks_without_progress = 20
checks_without_progress = 0
check_progress = 1
best_loss = np.float("inf")
n_iterations_per_epoch = len(X_train_exp) // batch_size

now = datetime.now().strftime("%Y%m%d_%H%M%S")
model_dir = "{}_augmented".format(now)
logdir = "tensorboard/faces/" + model_dir
file_writer = tf.summary.FileWriter(logdir=logdir, graph=tf.get_default_graph())
inception_v3_checkpoint_path = "models/cnn/inception_v3.ckpt"
augmented_training_path = "models/cnn/inception_v3_faces_augmented.ckpt"

with tf.Session() as sess:
    init.run()
    inception_saver.restore(sess, inception_v3_checkpoint_path)
    
    t0 = time.time()
    for epoch in range(n_epochs):
        start_index = 0
        
        for iteration in range(n_iterations_per_epoch):
            X_batch, y_batch = create_batch(X_train_exp, y_train_exp, start_index, batch_size)
            sess.run(training_op, {X: X_batch, y: y_batch})
            start_index += batch_size
            
        if epoch % show_progress == 0:
            train_summary = sess.run(train_acc_summary, {X: X_batch, y: y_batch})
            file_writer.add_summary(train_summary, (epoch+1))
            #Size for validation limited by GPU memory (68 images will work)
            valid_loss, valid_acc, valid_summary = sess.run([loss, accuracy, valid_merged_summary], {X: X_valid, y: y_valid})
            file_writer.add_summary(valid_summary, (epoch+1))
            print('Epoch: {} Validation Loss: {:.4f} Accuracy: {:4f}'.format(
                epoch+1, valid_loss, valid_acc))
            
        if valid_loss < best_loss:
            best_loss = valid_loss
            checks_without_progess = 0
            save_path = saver.save(sess, augmented_training_path)
            
        else:
            checks_without_progress += 1
            if checks_without_progress > max_checks_without_progress:
                print('Stopping Early! Loss has not improved in {} epochs'.format(
                    max_checks_without_progress))
                break
                
    t1 = time.time()
    
print('Total Training Time: {:.2f} minutes'.format( (t1-t0) / 60))
# Out:
# INFO:tensorflow:Restoring parameters from models/cnn/inception_v3.ckpt
# Epoch: 1 Validation Loss: 1.1123 Accuracy: 0.573529
# Epoch: 2 Validation Loss: 0.9927 Accuracy: 0.617647
# Epoch: 3 Validation Loss: 1.0175 Accuracy: 0.602941
# Epoch: 4 Validation Loss: 0.9210 Accuracy: 0.661765
# Epoch: 5 Validation Loss: 0.9502 Accuracy: 0.676471
# Epoch: 6 Validation Loss: 1.0442 Accuracy: 0.705882
# Epoch: 7 Validation Loss: 1.3256 Accuracy: 0.647059
# Epoch: 8 Validation Loss: 1.4516 Accuracy: 0.647059
# Epoch: 9 Validation Loss: 1.1426 Accuracy: 0.632353
# Epoch: 10 Validation Loss: 1.1084 Accuracy: 0.661765
# Epoch: 11 Validation Loss: 1.1072 Accuracy: 0.720588
# Epoch: 12 Validation Loss: 1.4951 Accuracy: 0.661765
# Epoch: 13 Validation Loss: 1.0699 Accuracy: 0.691177
# Epoch: 14 Validation Loss: 1.1920 Accuracy: 0.691177
# Epoch: 15 Validation Loss: 1.3776 Accuracy: 0.676471
# Epoch: 16 Validation Loss: 1.8172 Accuracy: 0.632353
# Epoch: 17 Validation Loss: 1.6500 Accuracy: 0.617647
# ...

# %% [markdown]
# ### Evaluating Augmented Model on Test Set

# %%
eval_batch_size = 32
n_iterations = len(X_test) // eval_batch_size

with tf.Session() as sess:
    saver.restore(sess, augmented_training_path)
    
    start_index = 0
    test_acc = {}
    t0 = time.time()
    
    for iteration in range(n_iterations):
        X_test_batch, y_test_batch = create_batch(X_test, y_test, start_index=start_index, batch_size=eval_batch_size)
        test_acc[iteration] = accuracy.eval({X: X_test_batch, y:y_test_batch})
        start_index += eval_batch_size

        print('Iteration: {} Batch Testing Accuracy: {:.2f}%'.format(
            iteration+1, test_acc[iteration] * 100))
    t1 = time.time()
    
    print('\nFinal Augmented with Clean Start Testing Accuracy: {:.4f}% on {} instances.'.format(
        np.mean(list(test_acc.values())) * 100, len(X_test)))
    
    print('Evaluation Time: {:.2f} seconds'.format( (t1 - t0)))
# Out:
# INFO:tensorflow:Restoring parameters from models/cnn/inception_v3_faces_augmented.ckpt
# Iteration: 1 Batch Testing Accuracy: 68.75%
# Iteration: 2 Batch Testing Accuracy: 65.62%
# Iteration: 3 Batch Testing Accuracy: 81.25%
# Iteration: 4 Batch Testing Accuracy: 71.88%
# Iteration: 5 Batch Testing Accuracy: 78.12%
# Iteration: 6 Batch Testing Accuracy: 68.75%
# Iteration: 7 Batch Testing Accuracy: 75.00%
# Iteration: 8 Batch Testing Accuracy: 78.12%
# Iteration: 9 Batch Testing Accuracy: 71.88%
# Iteration: 10 Batch Testing Accuracy: 81.25%
# Iteration: 11 Batch Testing Accuracy: 59.38%
#
# Final Augmented with Clean Start Testing Accuracy: 72.7273% on 361 instances.
# Evaluation Time: 28.73 seconds

# %% [markdown]
# That's great! Our accuracy on the test set has improved from 62.5% to 72.7% which is a relative improvement of 16%. This proves the [effectiveness of having more data](http://www.summarization.com/~radev/767w10/papers/Week06/TextRepresentation/Halevy.pdf) even when that data is artifically generated. Data augmentation is a common task for image recognition because creating labeled training sets can be time-consuming (that is what graduate students are for) and smart data augmentations can make the model more robust to differences in image details. This is crucial when lighting conditions and orientations in the real world are constantly in flux.

# %% [markdown]
# ### Training Augmented Model Starting from Un-Augmented Checkpoint

# %% [markdown]
# Another strategy we can use is to start off the training with the augmented dataset from the endpoint of the unaugmented training. What we are doing here is hoping that the same weights learned for the one trainable layer during the unagumented training will be useful on the augmented set as well. Ideally, this could speed up training (fewer epochs will be required for convergence on an optimal set of parameters) and it could result in an overall better network. Again, we will create different TensorBoard FileWriter directories and save locations so we can visualize the evolution of training cycles.

# %%
n_epochs = 100
batch_size = 32
max_checks_without_progress = 20
checks_without_progress = 0
check_progress = 1
best_loss = np.float("inf")
n_iterations_per_epoch = len(X_train_exp) // batch_size

now = datetime.now().strftime("%Y%m%d_%H%M%S")
model_dir = "{}_restart_augmented".format(now)
logdir = "tensorboard/faces/" + model_dir
file_writer = tf.summary.FileWriter(logdir=logdir, graph=tf.get_default_graph())
inception_v3_checkpoint_path = "models/cnn/inception_v3.ckpt"
restart_augmented_training_path = "models/cnn/inception_v3_faces_restart_augmented.ckpt"

with tf.Session() as sess:
    init.run()
    inception_saver.restore(sess, unaugmented_training_path)
    
    t0 = time.time()
    for epoch in range(n_epochs):
        start_index = 0
        
        for iteration in range(n_iterations_per_epoch):
            X_batch, y_batch = create_batch(X_train_exp, y_train_exp, start_index, batch_size)
            sess.run(training_op, {X: X_batch, y: y_batch})
            start_index += batch_size
            
        if epoch % show_progress == 0:
            train_summary = sess.run(train_acc_summary, {X: X_batch, y: y_batch})
            file_writer.add_summary(train_summary, (epoch+1))
            #Size for validation limited by GPU memory (68 images will work)
            valid_loss, valid_acc, valid_summary = sess.run([loss, accuracy, valid_merged_summary], {X: X_valid, y: y_valid})
            file_writer.add_summary(valid_summary, (epoch+1))
            print('Epoch: {} Validation Loss: {:.4f} Accuracy: {:4f}'.format(
                epoch+1, valid_loss, valid_acc))
            
        if valid_loss < best_loss:
            best_loss = valid_loss
            checks_without_progess = 0
            save_path = saver.save(sess, restart_augmented_training_path)
            
        else:
            checks_without_progress += 1
            if checks_without_progress > max_checks_without_progress:
                print('Stopping Early! Loss has not improved in {} epochs'.format(
                    max_checks_without_progress))
                break
                
    t1 = time.time()
    
print('Total Training Time: {:.2f} minutes'.format( (t1-t0) / 60))
# Out:
# INFO:tensorflow:Restoring parameters from models/cnn/inception_v3_faces_unaugmented.ckpt
# Epoch: 1 Validation Loss: 1.1120 Accuracy: 0.632353
# Epoch: 2 Validation Loss: 0.9959 Accuracy: 0.647059
# Epoch: 3 Validation Loss: 0.9968 Accuracy: 0.602941
# Epoch: 4 Validation Loss: 0.9446 Accuracy: 0.676471
# Epoch: 5 Validation Loss: 0.9778 Accuracy: 0.676471
# Epoch: 6 Validation Loss: 1.1402 Accuracy: 0.676471
# Epoch: 7 Validation Loss: 1.2427 Accuracy: 0.661765
# Epoch: 8 Validation Loss: 1.2677 Accuracy: 0.661765
# Epoch: 9 Validation Loss: 1.3726 Accuracy: 0.647059
# Epoch: 10 Validation Loss: 1.2670 Accuracy: 0.676471
# Epoch: 11 Validation Loss: 1.2496 Accuracy: 0.720588
# Epoch: 12 Validation Loss: 1.1765 Accuracy: 0.720588
# Epoch: 13 Validation Loss: 1.5270 Accuracy: 0.691177
# Epoch: 14 Validation Loss: 1.2012 Accuracy: 0.661765
# Epoch: 15 Validation Loss: 1.1381 Accuracy: 0.691177
# Epoch: 16 Validation Loss: 1.6300 Accuracy: 0.588235
# ...

# %% [markdown]
# The training time starting from the unaugmented checkpoint was essentially the same as starting with a clean model. The number of epochs was also exactly the same so training from the unaugmented checkpoint did not reduce the training time.

# %% [markdown]
# ### Evaluating on Testing Set

# %%
eval_batch_size = 32
n_iterations = len(X_test) // eval_batch_size

with tf.Session() as sess:
    saver.restore(sess, restart_augmented_training_path)
    
    start_index = 0
    test_acc = {}
    t0 = time.time()
    
    for iteration in range(n_iterations):
        X_test_batch, y_test_batch = create_batch(X_test, y_test, start_index=start_index, batch_size=eval_batch_size)
        test_acc[iteration] = accuracy.eval({X: X_test_batch, y:y_test_batch})
        start_index += eval_batch_size

        print('Iteration: {} Batch Testing Accuracy: {:.2f}%'.format(
            iteration+1, test_acc[iteration] * 100))
    t1 = time.time()
    
    print('\nFinal Augmented with Restart Testing Accuracy: {:.4f}% on {} instances.'.format(
        np.mean(list(test_acc.values())) * 100, len(X_test)))
    
    print('Evaluation Time: {:.2f} seconds'.format( (t1 - t0)))
# Out:
# INFO:tensorflow:Restoring parameters from models/cnn/inception_v3_faces_restart_augmented.ckpt
# Iteration: 1 Batch Testing Accuracy: 71.88%
# Iteration: 2 Batch Testing Accuracy: 68.75%
# Iteration: 3 Batch Testing Accuracy: 84.38%
# Iteration: 4 Batch Testing Accuracy: 71.88%
# Iteration: 5 Batch Testing Accuracy: 81.25%
# Iteration: 6 Batch Testing Accuracy: 68.75%
# Iteration: 7 Batch Testing Accuracy: 71.88%
# Iteration: 8 Batch Testing Accuracy: 81.25%
# Iteration: 9 Batch Testing Accuracy: 71.88%
# Iteration: 10 Batch Testing Accuracy: 81.25%
# Iteration: 11 Batch Testing Accuracy: 59.38%
#
# Final Augmented with Restart Testing Accuracy: 73.8636% on 361 instances.
# Evaluation Time: 28.60 seconds

# %% [markdown]
# Starting the augmented training from the un-augmented checkpoint did slightly improve accuracy (1.6% relative improvement). Again, there are any number of different methodologies that could be applied here, and we are only limited by the amount of training time we have. I have no doubt that there are better approaches, but I am limited by the resources of my laptop and the size of my [Google Cloud](https://cloud.google.com/compute/) free account balance.

# %% [markdown]
# ### Data Augmentation by Flipping Image Left to Right

# %% [markdown]
# We will try another simple data augmentation technique. This involves flipping the image from left to right, reversing the image. Once again, we are not altering the content of the image that we want the neural network to identify, the face itself, but rather the presentation of the face. We want the network to work no matter the orientation of a face that it must identify. There are any number of flips and rotations, but we will stick to a simple reversal of left to right.

# %%
images_flipped = []
labels_flipped = [] 

# Flip every image in the training set
for image, label in zip(X_train, y_train):
    images_flipped.append(np.fliplr(image))
    labels_flipped.append(label)

# Convert the flipped images and labels to arrays
images_flipped = np.array(images_flipped)
labels_flipped = np.array(labels_flipped)

# %% [markdown]
# Visualize flipped transformation.

# %%
ex_index = 22

plot_color_image(X_train[ex_index])
plt.title('Original Image of {}'.format(class_mapping[y_train[ex_index]]))
plt.show()

plot_color_image(images_flipped[ex_index])
plt.title('Left to Right Flipped Image')
plt.show()

# %%
ex_index = 652

plot_color_image(X_train[ex_index])
plt.title('Original Image of {}'.format(class_mapping[y_train[ex_index]]))
plt.show()

plot_color_image(images_flipped[ex_index])
plt.title('Left to Right Flipped Image')
plt.show()

# %% [markdown]
# As the images show, the content of the images has not been altered, only flipped from left to right.

# %%
X_train_with_flip = np.concatenate((X_train, images_flipped))
y_train_with_flip = np.concatenate((y_train, labels_flipped))

# %%
print(X_train_with_flip.shape, y_train_with_flip.shape)
# Out:
# (2054, 250, 250, 3) (2054,)

# %% [markdown]
# The dataset has been doubled in this augmentation. Again, we can train with a fresh pre-trained model and then starting from the un-augmented checkpoint.

# %% [markdown]
# ### Train with Flipped Images on Fresh Model

# %%
n_epochs = 100
batch_size = 32
max_checks_without_progress = 20
checks_without_progress = 0
check_progress = 1
best_loss = np.float("inf")
n_iterations_per_epoch = len(X_train_with_flip) // batch_size

now = datetime.now().strftime("%Y%m%d_%H%M%S")
model_dir = "{}_flipped".format(now)
logdir = "tensorboard/faces/" + model_dir
file_writer = tf.summary.FileWriter(logdir=logdir, graph=tf.get_default_graph())
inception_v3_checkpoint_path = "models/cnn/inception_v3.ckpt"
flipped_training_path = "models/cnn/inception_v3_faces_flipped.ckpt"

with tf.Session() as sess:
    init.run()
    inception_saver.restore(sess, inception_v3_checkpoint_path)
    
    t0 = time.time()
    for epoch in range(n_epochs):
        start_index = 0 
        
        for iteration in range(n_iterations_per_epoch):
            X_batch, y_batch = create_batch(X_train_with_flip, y_train_with_flip, start_index, batch_size)
            sess.run(training_op, {X: X_batch, y: y_batch})
            start_index += batch_size
            
        if epoch % show_progress == 0:
            train_summary = sess.run(train_acc_summary, {X: X_batch, y: y_batch})
            file_writer.add_summary(train_summary, (epoch+1))
            
            # Size for validation limited by GPU memory (68 images will work)
            valid_loss, valid_acc, valid_summary = sess.run([loss, accuracy, valid_merged_summary], {X: X_valid, y: y_valid})
            file_writer.add_summary(valid_summary, (epoch+1))
            print('Epoch: {} Validation Loss: {:.4f} Accuracy: {:4f}'.format(
                epoch+1, valid_loss, valid_acc))
            
        if valid_loss < best_loss:
            best_loss = valid_loss
            checks_without_progess = 0
            save_path = saver.save(sess, flipped_training_path)
            
        else:
            checks_without_progress += 1
            if checks_without_progress > max_checks_without_progress:
                print('Stopping Early! Loss has not improved in {} epochs'.format(
                    max_checks_without_progress))
                break
                
    t1 = time.time()
    
print('Total Training Time: {:.2f} minutes'.format( (t1-t0) / 60))
# Out:
# INFO:tensorflow:Restoring parameters from models/cnn/inception_v3.ckpt
# Epoch: 1 Validation Loss: 1.4496 Accuracy: 0.514706
# Epoch: 2 Validation Loss: 1.1961 Accuracy: 0.588235
# Epoch: 3 Validation Loss: 1.3385 Accuracy: 0.544118
# Epoch: 4 Validation Loss: 1.3663 Accuracy: 0.602941
# Epoch: 5 Validation Loss: 1.1692 Accuracy: 0.632353
# Epoch: 6 Validation Loss: 1.2436 Accuracy: 0.573529
# Epoch: 7 Validation Loss: 1.8220 Accuracy: 0.441176
# Epoch: 8 Validation Loss: 1.9081 Accuracy: 0.441177
# Epoch: 9 Validation Loss: 1.1736 Accuracy: 0.544118
# Epoch: 10 Validation Loss: 1.3712 Accuracy: 0.588235
# Epoch: 11 Validation Loss: 1.4327 Accuracy: 0.647059
# Epoch: 12 Validation Loss: 1.7379 Accuracy: 0.558824
# Epoch: 13 Validation Loss: 1.8620 Accuracy: 0.529412
# Epoch: 14 Validation Loss: 1.4102 Accuracy: 0.647059
# Epoch: 15 Validation Loss: 1.9546 Accuracy: 0.573529
# Epoch: 16 Validation Loss: 2.1959 Accuracy: 0.588235
# Epoch: 17 Validation Loss: 1.9413 Accuracy: 0.647059
# ...

# %% [markdown]
# ### Evaluate on Testing Set

# %%
eval_batch_size = 32
n_iterations = len(X_test) // eval_batch_size

with tf.Session() as sess:
    saver.restore(sess, flipped_training_path)
    
    start_index = 0
    test_acc = {}
    t0 = time.time()
    
    for iteration in range(n_iterations):
        X_test_batch, y_test_batch = create_batch(X_test, y_test, start_index, batch_size=eval_batch_size)
        test_acc[iteration] = accuracy.eval({X: X_test_batch, y:y_test_batch})
        start_index += eval_batch_size
        print('Iteration: {} Batch Testing Accuracy: {:.2f}%'.format(
            iteration+1, test_acc[iteration] * 100))
    
    t1 = time.time()
    print('Final Flipped with Clean Start Testing Accuracy: {:.4f}% on {} instances.'.format(
        np.mean(list(test_acc.values())) * 100, len(X_test)))
    
    print('Evaluation Time: {:.2f} seconds'.format( (t1-t0)))
# Out:
# INFO:tensorflow:Restoring parameters from models/cnn/inception_v3_faces_flipped.ckpt
# Iteration: 1 Batch Testing Accuracy: 65.62%
# Iteration: 2 Batch Testing Accuracy: 68.75%
# Iteration: 3 Batch Testing Accuracy: 65.62%
# Iteration: 4 Batch Testing Accuracy: 62.50%
# Iteration: 5 Batch Testing Accuracy: 68.75%
# Iteration: 6 Batch Testing Accuracy: 68.75%
# Iteration: 7 Batch Testing Accuracy: 68.75%
# Iteration: 8 Batch Testing Accuracy: 65.62%
# Iteration: 9 Batch Testing Accuracy: 59.38%
# Iteration: 10 Batch Testing Accuracy: 71.88%
# Iteration: 11 Batch Testing Accuracy: 62.50%
# Final Flipped with Clean Start Testing Accuracy: 66.1932% on 361 instances.
# Evaluation Time: 41.99 seconds

# %% [markdown]
# ### Train with Flipped Images Starting from Augmented Checkpoint

# %% [markdown]
# We can now do the same procedure that we did with the flipped images where we train beginning with the checkpoint from a previous model. In this case, we will use the best previous model, which was the augmented model that started from the unaugmented checkpoint. The complete order of training for this model is thus: trained by Google on the 1.2 million images and 1000 classes in the ImageNet training dataset, the last layer before the output was trained on our original dataset of 1027 labeled faces from 10 classes, then the last layer was trained on the augmented dataset of 5135 images, and finally, it will be trained on the dataset with the original plus left to right flipped images. However, this sequence of training does not mean that the model will perform better on the test set as it could easily overfit the training data.

# %%
n_epochs = 100
batch_size = 32
max_checks_without_progress = 20
checks_without_progress = 0
check_progress = 1
best_loss = np.float("inf")
n_iterations_per_epoch = len(X_train_with_flip) // batch_size

now = datetime.now().strftime("%Y%m%d_%H%M%S")
model_dir = "{}_restart_flipped".format(now)
logdir = "tensorboard/faces/" + model_dir
file_writer = tf.summary.FileWriter(logdir=logdir, graph=tf.get_default_graph())
inception_v3_checkpoint_path = "models/cnn/inception_v3.ckpt"
restart_flipped_training_path = "models/cnn/inception_v3_faces_restart_flipped.ckpt"

with tf.Session() as sess:
    init.run()
    inception_saver.restore(sess, restart_augmented_training_path)
    
    t0 = time.time()
    for epoch in range(n_epochs):
        start_index = 0 
        
        for iteration in range(n_iterations_per_epoch):
            X_batch, y_batch = create_batch(X_train_with_flip, y_train_with_flip, start_index, batch_size)
            sess.run(training_op, {X: X_batch, y: y_batch})
            start_index += batch_size
            
        if epoch % show_progress == 0:
            train_summary = sess.run(train_acc_summary, {X: X_batch, y: y_batch})
            file_writer.add_summary(train_summary, (epoch+1))
            
            # Size for validation limited by GPU memory (68 images will work)
            valid_loss, valid_acc, valid_summary = sess.run([loss, accuracy, valid_merged_summary], {X: X_valid, y: y_valid})
            file_writer.add_summary(valid_summary, (epoch+1))
            print('Epoch: {} Validation Loss: {:.4f} Accuracy: {:4f}'.format(
                epoch+1, valid_loss, valid_acc))
            
        if valid_loss < best_loss:
            best_loss = valid_loss
            checks_without_progess = 0
            save_path = saver.save(sess, flipped_training_path)
            
        else:
            checks_without_progress += 1
            if checks_without_progress > max_checks_without_progress:
                print('Stopping Early! Loss has not improved in {} epochs'.format(
                    max_checks_without_progress))
                break
                
    t1 = time.time()
    
print('Total Training Time: {:.2f} minutes'.format( (t1-t0) / 60))
# Out:
# INFO:tensorflow:Restoring parameters from models/cnn/inception_v3_faces_restart_augmented.ckpt
# Epoch: 1 Validation Loss: 1.3838 Accuracy: 0.558824
# Epoch: 2 Validation Loss: 1.2436 Accuracy: 0.602941
# Epoch: 3 Validation Loss: 1.3525 Accuracy: 0.514706
# Epoch: 4 Validation Loss: 1.2664 Accuracy: 0.573529
# Epoch: 5 Validation Loss: 1.2893 Accuracy: 0.632353
# Epoch: 6 Validation Loss: 1.3480 Accuracy: 0.602941
# Epoch: 7 Validation Loss: 1.3421 Accuracy: 0.544118
# Epoch: 8 Validation Loss: 1.6785 Accuracy: 0.455882
# Epoch: 9 Validation Loss: 1.4709 Accuracy: 0.558824
# Epoch: 10 Validation Loss: 1.3648 Accuracy: 0.558824
# Epoch: 11 Validation Loss: 1.6617 Accuracy: 0.558824
# Epoch: 12 Validation Loss: 2.0965 Accuracy: 0.573529
# Epoch: 13 Validation Loss: 2.1080 Accuracy: 0.588235
# Epoch: 14 Validation Loss: 1.9821 Accuracy: 0.558824
# Epoch: 15 Validation Loss: 2.0218 Accuracy: 0.573529
# Epoch: 16 Validation Loss: 2.1053 Accuracy: 0.588235
# ...

# %%
eval_batch_size = 32
n_iterations = len(X_test) // eval_batch_size

with tf.Session() as sess:
    saver.restore(sess, flipped_training_path)
    
    start_index = 0
    test_acc = {}
    t0 = time.time()
    
    for iteration in range(n_iterations):
        X_test_batch, y_test_batch = create_batch(X_test, y_test, start_index, batch_size=eval_batch_size)
        test_acc[iteration] = accuracy.eval({X: X_test_batch, y:y_test_batch})
        start_index += eval_batch_size
        print('Iteration: {} Batch Testing Accuracy: {:.2f}%'.format(
            iteration+1, test_acc[iteration] * 100))
    
    t1 = time.time()
    print('Final Flipped with Restart Testing Accuracy: {:.4f}% on {} instances.'.format(
        np.mean(list(test_acc.values())) * 100, len(X_test)))
    
    print('Evaluation Time: {:.2f} seconds'.format( (t1-t0)))
# Out:
# INFO:tensorflow:Restoring parameters from models/cnn/inception_v3_faces_flipped.ckpt
# Iteration: 1 Batch Testing Accuracy: 71.88%
# Iteration: 2 Batch Testing Accuracy: 68.75%
# Iteration: 3 Batch Testing Accuracy: 62.50%
# Iteration: 4 Batch Testing Accuracy: 62.50%
# Iteration: 5 Batch Testing Accuracy: 53.12%
# Iteration: 6 Batch Testing Accuracy: 56.25%
# Iteration: 7 Batch Testing Accuracy: 62.50%
# Iteration: 8 Batch Testing Accuracy: 62.50%
# Iteration: 9 Batch Testing Accuracy: 65.62%
# Iteration: 10 Batch Testing Accuracy: 53.12%
# Iteration: 11 Batch Testing Accuracy: 46.88%
# Final Flipped with Restart Testing Accuracy: 60.5114% on 361 instances.
# Evaluation Time: 29.61 seconds

# %% [markdown]
# ## Visualizing Performance of Best Convolutional Neural Network

# %%
def classify_image(index, images=X_test, labels=y_test):
    image_array = images[index]
    label = class_mapping[labels[index]]
    
    prepared_image = prepare_image(image_array)
    prepared_image = np.reshape(prepared_image, newshape=(-1, 299, 299, 3))
    
    with tf.Session() as sess:
        saver.restore(sess, restart_augmented_training_path)
        predictions = sess.run(probability, {X: prepared_image})
    
    predictions = [(i, prediction) for i, prediction in enumerate(predictions[0])]
    predictions = sorted(predictions, key=lambda x: x[1], reverse=True)
    print('\nCorrect Answer: {}'.format(label)) 
    print('\nPredictions:')
    for prediction in predictions:
        class_label = prediction[0]
        probability_value = prediction[1]
        label = class_mapping[class_label]
        print("{:26}: {:.2f}%".format(label, probability_value * 100))
        
    plot_color_image(image_array)
    return predictions

# %%
predictions = classify_image(20)
# Out:
# INFO:tensorflow:Restoring parameters from models/cnn/inception_v3_faces_restart_augmented.ckpt
#
# Correct Answer: George_W_Bush
#
# Predictions:
# George_W_Bush             : 93.69%
# Tony_Blair                : 2.57%
# Hugo_Chavez               : 1.18%
# Ariel_Sharon              : 0.93%
# Junichiro_Koizumi         : 0.58%
# Gerhard_Schroeder         : 0.53%
# Jean_Chretien             : 0.26%
# Colin_Powell              : 0.19%
# John_Ashcroft             : 0.05%
# Donald_Rumsfeld           : 0.02%

# %%
class_mapping
# Out:
# {0: 'John_Ashcroft',
#  1: 'Jean_Chretien',
#  2: 'Junichiro_Koizumi',
#  3: 'Hugo_Chavez',
#  4: 'Ariel_Sharon',
#  5: 'Gerhard_Schroeder',
#  6: 'Donald_Rumsfeld',
#  7: 'Tony_Blair',
#  8: 'Colin_Powell',
#  9: 'George_W_Bush'}

# %%
one_index = {}

# Find one index of image of each individual
for label in class_mapping:
    while label not in one_index.keys():
        potential_index = np.random.randint(len(X_test))
        if y_test[potential_index] == label:
            one_index[label] = potential_index

# %%
one_index
# Out:
# {0: 346, 1: 123, 2: 305, 3: 140, 4: 9, 5: 103, 6: 220, 7: 82, 8: 70, 9: 291}

# %%
predictions = classify_image(346)
# Out:
# INFO:tensorflow:Restoring parameters from models/cnn/inception_v3_faces_restart_augmented.ckpt
#
# Correct Answer: John_Ashcroft
#
# Predictions:
# John_Ashcroft             : 81.46%
# George_W_Bush             : 7.45%
# Donald_Rumsfeld           : 6.56%
# Tony_Blair                : 2.19%
# Hugo_Chavez               : 1.74%
# Junichiro_Koizumi         : 0.35%
# Colin_Powell              : 0.19%
# Gerhard_Schroeder         : 0.03%
# Ariel_Sharon              : 0.01%
# Jean_Chretien             : 0.00%

# %%
predictions = classify_image(9)
# Out:
# INFO:tensorflow:Restoring parameters from models/cnn/inception_v3_faces_restart_augmented.ckpt
#
# Correct Answer: Ariel_Sharon
#
# Predictions:
# Colin_Powell              : 51.56%
# Tony_Blair                : 26.33%
# Gerhard_Schroeder         : 12.32%
# John_Ashcroft             : 3.31%
# Donald_Rumsfeld           : 2.88%
# George_W_Bush             : 1.98%
# Ariel_Sharon              : 1.29%
# Junichiro_Koizumi         : 0.18%
# Jean_Chretien             : 0.11%
# Hugo_Chavez               : 0.03%

# %%
predictions = classify_image(123)
# Out:
# INFO:tensorflow:Restoring parameters from models/cnn/inception_v3_faces_restart_augmented.ckpt
#
# Correct Answer: Jean_Chretien
#
# Predictions:
# Jean_Chretien             : 47.62%
# Ariel_Sharon              : 24.85%
# Tony_Blair                : 8.94%
# George_W_Bush             : 8.94%
# Gerhard_Schroeder         : 4.65%
# Donald_Rumsfeld           : 3.64%
# Colin_Powell              : 0.76%
# Junichiro_Koizumi         : 0.51%
# John_Ashcroft             : 0.05%
# Hugo_Chavez               : 0.04%

# %% [markdown]
# ### Analyzing Distribution of Test Predictions

# %%
eval_batch_size = 32
n_iterations = len(X_test) // eval_batch_size

# Evaluation with saved predictions
with tf.Session() as sess:
    saver.restore(sess, restart_augmented_training_path)
    
    test_predictions = []
    start_index = 0
    
    # Add each set of predictions to a list
    for iteration in range(n_iterations):
        X_test_batch, y_test_batch = create_batch(X_test, y_test, start_index, batch_size=eval_batch_size)
        test_predictions.append(probability.eval({X: X_test_batch, y: y_test_batch}))
        start_index += eval_batch_size
# Out:
# INFO:tensorflow:Restoring parameters from models/cnn/inception_v3_faces_restart_augmented.ckpt

# %%
# Convert list of predictions to np array
test_predictions = np.array(test_predictions)
test_predictions.shape
# Out:
# (11, 32, 10)

# %%
# Reshape predictions to correct shape and generate label array
test_predictions = np.reshape(test_predictions, (-1, 10))
test_predictions_label = np.argmax(test_predictions, axis=1)
test_predictions_label.shape
# Out:
# (352,)

# %%
# A few of the testing examples are left off by the batching process
y_test_eval = y_test[:352]

# %%
# Make sure that accuracy agrees with earlier evaluation
test_accuracy = np.mean(np.equal(test_predictions_label, y_test_eval))
print("Test Accuracy: {:.2f}%".format(test_accuracy*100))
# Out:
# Test Accuracy: 73.86%

# %%
print('Individual: \t Composition of Test Set \t Composition of Predictions')
total_test_images = len(y_test_eval)

for label, individual in class_mapping.items():
    n_test_images = Counter(y_test_eval)[label]
    n_predictions = Counter(test_predictions_label)[label] 
    print("{:26} {:5.2f}% {:26.2f}%".format(
        individual, n_test_images / total_test_images * 100, n_predictions / total_test_images * 100))
# Out:
# Individual: 	 Composition of Test Set 	 Composition of Predictions
# John_Ashcroft               2.84%                       1.99%
# Jean_Chretien               3.69%                       1.70%
# Junichiro_Koizumi           4.26%                       4.83%
# Hugo_Chavez                 4.83%                       2.84%
# Ariel_Sharon                5.40%                       4.83%
# Gerhard_Schroeder           7.67%                       6.82%
# Donald_Rumsfeld             7.95%                      10.23%
# Tony_Blair                  9.94%                       9.09%
# Colin_Powell               15.91%                      15.34%
# George_W_Bush              37.50%                      42.33%

# %%
# Visualize distribution of images in test set
bins = np.arange(11)
fig, ax = plt.subplots(figsize=(14, 8))
plt.subplots_adjust(wspace=0.25)
plt.subplot(1,2,1)
plt.hist(y_test_eval, bins=bins, lw=1.2, edgecolor='black')
plt.title('Frequency of Classes in Test Set'); plt.xlabel('Class'); plt.ylabel('Count');
names = list(class_mapping.values())
xlabels = [name.split("_")[1] for name in names]
plt.xticks(bins+0.5, xlabels, rotation='vertical');

plt.subplot(1,2,2)
# Visualize distribution of images in predictions
bins = np.arange(11)
plt.hist(test_predictions_label, bins=bins, lw=1.2, edgecolor='black')
plt.title('Frequency of Classes in Predictions'); plt.xlabel('Class'); plt.ylabel('Count');
names = list(class_mapping.values())
xlabels = [name.split("_")[1] for name in names]
plt.xticks(bins+0.5, xlabels, rotation='vertical');

# %%
relative_differences = []

for label, individual in class_mapping.items():
    n_test_images = Counter(y_test_eval)[label]
    n_predictions = Counter(test_predictions_label)[label] 
    n_test_pct = n_test_images / total_test_images
    n_predictions_pct = n_predictions / total_test_images
    
    relative_differences.append((n_predictions_pct - n_test_pct) / n_test_pct * 100)
    
# Assign colors according to sign
colors = ['orange' if difference < 0.0 else 'blue' for difference in relative_differences]

# Visualize relative difference in 
bins = np.arange(10)
fig, ax = plt.subplots()
plt.bar(bins, relative_differences, lw=1.2, color=colors, edgecolor='black')
plt.title('Relative Differences between Test Set and Prediction Composition'); plt.xlabel('Class'); plt.ylabel('Relative Difference (%)');
names = list(class_mapping.values())
xlabels = [name.split("_")[1] for name in names]
plt.xticks(bins, xlabels, rotation='vertical');

# %%
my_array = [plt.imread("images/Self.jpg")]
my_label = ['me']

# %%
predictions = classify_image(0, images=my_array)
# Out:
# INFO:tensorflow:Restoring parameters from models/cnn/inception_v3_faces_restart_augmented.ckpt
#
# Correct Answer: George_W_Bush
#
# Predictions:
# George_W_Bush             : 52.30%
# Tony_Blair                : 39.42%
# Jean_Chretien             : 6.43%
# Donald_Rumsfeld           : 1.84%
# Ariel_Sharon              : 0.00%
# Colin_Powell              : 0.00%
# Gerhard_Schroeder         : 0.00%
# John_Ashcroft             : 0.00%
# Junichiro_Koizumi         : 0.00%
# Hugo_Chavez               : 0.00%

# %%
import matplotlib.pyplot as plt
father_array = [plt.imread("images/father_circa_college.jpg")]

# %%
from scipy.misc import imresize

# Function takes in an image array and returns the resized and normalized array
def prepare_image(image, target_height=299, target_width=299):
    image = imresize(image, (target_width, target_height))
    return image.astype(np.float32) / 255

# %%
restart_augmented_training_path = "models/cnn/inception_v3_faces_restart_augmented.ckpt"



with tf.Session() as sess:
    prepared_image = prepare_image(father_array[0])
    prepared_image = np.reshape(prepared_image, newshape=(-1, 299, 299, 3))
    saver.restore(sess, restart_augmented_training_path)
    predictions = sess.run(probability, {X: prepared_image})
    
    predictions = [(i, prediction) for i, prediction in enumerate(predictions[0])]
    predictions = sorted(predictions, key=lambda x: x[1], reverse=True)
    print('\nPredictions:')
    for prediction in predictions:
        class_label = prediction[0]
        probability_value = prediction[1]
        label = class_mapping[class_label]
        print("{:26}: {:.2f}%".format(label, probability_value * 100))
        
    plt.imshow(father_array[0].astype(np.uint8), interpolation='nearest')
    plt.axis('off')
    plt.show()
# Out:
# INFO:tensorflow:Restoring parameters from models/cnn/inception_v3_faces_restart_augmented.ckpt
#
# Predictions:
# Junichiro_Koizumi         : 99.84%
# Tony_Blair                : 0.15%
# George_W_Bush             : 0.01%
# Jean_Chretien             : 0.00%
# Donald_Rumsfeld           : 0.00%
# Gerhard_Schroeder         : 0.00%
# Colin_Powell              : 0.00%
# John_Ashcroft             : 0.00%
# Ariel_Sharon              : 0.00%
# Hugo_Chavez               : 0.00%

# %%
prepared_image = np.reshape(prepared_image, newshape=(-1, 299, 299, 3))

# %%
prepared_image.shape
# Out:
# (1, 299, 299, 3)

# %%
prepared_image = np.squeeze(prepared_image)

# %%
prepared_image.shape
# Out:
# (299, 299, 3)
